# %%
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
nba_pergame=pd.read_csv("nba_pergame_1.csv")
nba_basic=nba_pergame[nba_pergame['G']>40]
nba_basic.head()
# Out:
#    Rk                    Player Pos  Age   Tm  ...  BLK  TOV   PF   PTS   PlayerID
# 0   1          Precious Achiuwa  PF   21  MIA  ...  0.5  0.7  1.5   5.0  achiupr01
# 2   3              Steven Adams   C   27  NOP  ...  0.7  1.3  1.9   7.6  adamsst01
# 3   4               Bam Adebayo   C   23  MIA  ...  1.0  2.6  2.3  18.7  adebaba01
# 8   7  Nickeil Alexander-Walker  SG   22  NOP  ...  0.5  1.5  1.9  11.0  alexani01
# 9   8             Grayson Allen  SG   25  MEM  ...  0.2  1.0  1.4  10.6  allengr01
#
# [5 rows x 31 columns]

# %%
nba_advanced=pd.read_csv("nba_advanced_1.csv")
nba_adv=nba_advanced[nba_advanced['G']>40]
nba_adv.head()
# Out:
#    Rk                    Player Pos  Age   Tm  ...  OBPM  DBPM  BPM  VORP   PlayerID
# 0   1          Precious Achiuwa  PF   21  MIA  ...  -3.5  -0.9 -4.5  -0.5  achiupr01
# 2   3              Steven Adams   C   27  NOP  ...  -0.3  -0.5 -0.8   0.5  adamsst01
# 3   4               Bam Adebayo   C   23  MIA  ...   2.9   1.9  4.7   3.6  adebaba01
# 8   7  Nickeil Alexander-Walker  SG   22  NOP  ...  -1.4  -0.2 -1.6   0.1  alexani01
# 9   8             Grayson Allen  SG   25  MEM  ...  -0.4  -0.1 -0.5   0.5  allengr01
#
# [5 rows x 28 columns]

# %%
nba_adv.count()
# Out:
# Rk          329
# Player      329
# Pos         329
# Age         329
# Tm          329
# G           329
# MP          329
# PER         329
# TS%         329
# 3PAr        329
# FTr         329
# ORB%        329
# DRB%        329
# TRB%        329
# AST%        329
# STL%        329
# BLK%        329
# TOV%        329
# USG%        329
# OWS         329
# DWS         329
# WS          329
# WS/48       329
# OBPM        329
# DBPM        329
# BPM         329
# VORP        329
# PlayerID    329
# dtype: int64

# %%
nba_adv.dropna().count()
# Out:
# Rk          329
# Player      329
# Pos         329
# Age         329
# Tm          329
# G           329
# MP          329
# PER         329
# TS%         329
# 3PAr        329
# FTr         329
# ORB%        329
# DRB%        329
# TRB%        329
# AST%        329
# STL%        329
# BLK%        329
# TOV%        329
# USG%        329
# OWS         329
# DWS         329
# WS          329
# WS/48       329
# OBPM        329
# DBPM        329
# BPM         329
# VORP        329
# PlayerID    329
# dtype: int64

# %%
nbthree=nba_basic[nba_basic['3PA']>5].sort_values('3P%',ascending=False)
nbthree[['Player','Tm','Pos','3P%']].head()
# Out:
#                  Player   Tm Pos    3P%
# 269          Joe Harris  BRK  SF  0.475
# 459       Marcus Morris  LAC  PF  0.473
# 314          Joe Ingles  UTA  SF  0.451
# 527  Michael Porter Jr.  DEN  SF  0.445
# 535       Norman Powell  TOR  SG  0.439

# %%
nba_basic[['Player','Tm','Pos','PTS']].sort_values('PTS',ascending=False).head()
# Out:
#                     Player   Tm Pos   PTS
# 151          Stephen Curry  GSW  PG  32.0
# 45            Bradley Beal  WAS  SG  31.3
# 396         Damian Lillard  POR  PG  28.8
# 189            Joel Embiid  PHI   C  28.5
# 17   Giannis Antetokounmpo  MIL  PF  28.1

# %%
nba_basic[['Player','Tm','Pos','AST']].sort_values('AST',ascending=False).head()
# Out:
#                 Player   Tm    Pos   AST
# 675  Russell Westbrook  WAS     PG  11.7
# 257       James Harden  TOT  PG-SG  10.8
# 702         Trae Young  ATL     PG   9.4
# 237     Draymond Green  GSW     PF   8.9
# 510         Chris Paul  PHO     PG   8.9

# %%
nba_basic[['Player','Tm','Pos','TRB']].sort_values('TRB',ascending=False).head()
# Out:
#                 Player   Tm Pos   TRB
# 113       Clint Capela  ATL   C  14.3
# 228        Rudy Gobert  UTA   C  13.5
# 647  Jonas Valančiūnas  MEM   C  12.5
# 178     Andre Drummond  TOT   C  12.0
# 577   Domantas Sabonis  IND  PF  12.0

# %%
nba_adv[['Player','Tm','Pos','BPM']].sort_values('BPM',ascending=False).head()
# Out:
#                     Player   Tm Pos   BPM
# 343           Nikola Jokić  DEN   C  11.7
# 17   Giannis Antetokounmpo  MIL  PF   8.8
# 151          Stephen Curry  GSW  PG   8.1
# 106           Jimmy Butler  MIA  SF   7.5
# 328           LeBron James  LAL  PG   7.5

# %%
nba_adv[['Player','Tm','Pos','WS']].sort_values('WS',ascending=False).head()
# Out:
#                     Player   Tm Pos    WS
# 343           Nikola Jokić  DEN   C  15.6
# 228            Rudy Gobert  UTA   C  11.3
# 396         Damian Lillard  POR  PG  10.4
# 17   Giannis Antetokounmpo  MIL  PF  10.2
# 106           Jimmy Butler  MIA  SF   9.3

# %%
nba_adv[['Player','Tm','Pos','DBPM']].sort_values('DBPM',ascending=False).head()
# Out:
#                Player   Tm Pos  DBPM
# 631  Matisse Thybulle  PHI  SG   4.3
# 475      Nerlens Noel  NYK   C   3.5
# 220        Marc Gasol  LAL   C   3.3
# 237    Draymond Green  GSW  PF   3.3
# 687   Robert Williams  BOS   C   3.1

# %%
nba_adv[['Player','Tm','Pos','OBPM']].sort_values('OBPM',ascending=False).head()
# Out:
#                     Player   Tm    Pos  OBPM
# 343           Nikola Jokić  DEN      C   9.2
# 151          Stephen Curry  GSW     PG   8.1
# 396         Damian Lillard  POR     PG   7.4
# 257           James Harden  TOT  PG-SG   6.2
# 17   Giannis Antetokounmpo  MIL     PF   6.2

# %%
nba_adv[['Player','Tm','Pos','PER']].sort_values('PER',ascending=False).head()
# Out:
#                     Player   Tm Pos   PER
# 343           Nikola Jokić  DEN   C  31.3
# 189            Joel Embiid  PHI   C  30.3
# 17   Giannis Antetokounmpo  MIL  PF  29.2
# 688        Zion Williamson  NOP  PF  27.1
# 106           Jimmy Butler  MIA  SF  26.5

# %%
nba_adv[['Player','Tm','Pos','VORP']].sort_values('VORP',ascending=False).head()
# Out:
#                     Player   Tm Pos  VORP
# 343           Nikola Jokić  DEN   C   8.6
# 151          Stephen Curry  GSW  PG   5.5
# 17   Giannis Antetokounmpo  MIL  PF   5.5
# 171            Luka Dončić  DAL  PG   5.0
# 396         Damian Lillard  POR  PG   4.8

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.scatterplot('PER','TS%',data=nba_adv,style='Pos',hue='Tm',legend='full',s=100)
plt.text(30.3+0.1, 0.636, "Joel Embiid", horizontalalignment='left', size='medium', color='black')
plt.text(31.3+0.1, 0.647, "Nikola Jokic", horizontalalignment='left', size='medium', color='black')
plt.text(17.1+0.1, 0.736, "DeAndre Jordan", horizontalalignment='left', size='medium', color='black')
plt.text(25.7+0.1, 0.719, "Robert Williams", horizontalalignment='left', size='medium', color='black')
plt.title("PER vs TS%", fontsize = 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'PER vs TS%')

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.scatterplot('WS','BPM',data=nba_adv,style='Pos',hue='Tm',legend='full',s=100)
plt.text(15.6+0.1, 11.7, "Nikola Jokic", horizontalalignment='left', size='medium', color='black')
plt.text(10.2+0.1, 8.8, "Giannis Antetokounmpo", horizontalalignment='left', size='medium', color='black')
plt.title("WS vs BPM", fontsize = 20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'WS vs BPM')
